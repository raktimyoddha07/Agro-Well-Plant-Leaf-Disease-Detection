# %%
import os
import cv2
import numpy as np
from sklearn.cluster import KMeans
from tqdm import tqdm


def segment_image_kmeans(image_path, n_clusters=3):
    """
    Perform K-means clustering on the pixels of the image to segment it into n_clusters colors.
    Returns the segmented image.
    """
    # Read image
    img = cv2.imread(image_path)
    if img is None:
        return None
    # Convert to RGB
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Reshape to (num_pixels, 3)
    pixels = img_rgb.reshape(-1, 3)
    # Apply KMeans
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(pixels)
    centers = np.uint8(kmeans.cluster_centers_)
    # Recreate segmented image
    segmented = centers[labels].reshape(img_rgb.shape)
    # Convert back to BGR for saving
    segmented_bgr = cv2.cvtColor(segmented, cv2.COLOR_RGB2BGR)
    return segmented_bgr


def process_dataset_kmeans(source_root, dest_root, n_clusters=3):
    """
    Process all images under source_root/train, /val, /test splits,
    perform K-means segmentation, and save segmented images under dest_root,
    preserving the split and class folder structure.
    """
    splits = ['train', 'val', 'test']
    for split in splits:
        src_split = os.path.join(source_root, split)
        dst_split = os.path.join(dest_root, split)
        if not os.path.isdir(src_split):
            continue
        # Iterate classes
        for class_name in os.listdir(src_split):
            src_class = os.path.join(src_split, class_name)
            dst_class = os.path.join(dst_split, class_name)
            if not os.path.isdir(src_class):
                continue
            os.makedirs(dst_class, exist_ok=True)
            # Process each image
            for img_file in tqdm(os.listdir(src_class), desc=f"{split}/{class_name}"):
                if not img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    continue
                src_img_path = os.path.join(src_class, img_file)
                segmented = segment_image_kmeans(src_img_path, n_clusters=n_clusters)
                if segmented is None:
                    continue
                # Save segmented image with same filename
                dst_img_path = os.path.join(dst_class, img_file)
                cv2.imwrite(dst_img_path, segmented)
    print("Segmentation complete. Segmented images saved under dest_root.")


if __name__ == "__main__":
    source_root = r"C:\Users\rakti\Downloads\a\Final-project\Datasets\npld_bg_removed"
    dest_root   = r"C:\Users\rakti\Downloads\a\Final-project\Datasets\npld_kmeans"
    process_dataset_kmeans(source_root, dest_root, n_clusters=3)
# Out:
# train/1 1 Apple healthy: 100%|██████████| 351/351 [00:09<00:00, 35.24it/s]
# train/1 2 Apple Apple scab: 100%|██████████| 352/352 [00:10<00:00, 34.52it/s]
# train/1 3 Apple Black rot: 100%|██████████| 347/347 [00:10<00:00, 31.76it/s]
# train/1 4 Apple Cedar apple rust: 100%|██████████| 308/308 [00:08<00:00, 34.56it/s]
# train/2 1 Tomato healthy: 100%|██████████| 336/336 [00:10<00:00, 32.84it/s]
# train/2 2 Tomato Early blight: 100%|██████████| 336/336 [00:10<00:00, 30.74it/s]
# train/2 3 Tomato Late blight: 100%|██████████| 324/324 [00:10<00:00, 30.94it/s]
# train/2 4 Tomato Bacterial spot: 100%|██████████| 297/297 [00:09<00:00, 31.34it/s]
# train/2 5 Tomato Leaf Mold: 100%|██████████| 329/329 [00:09<00:00, 33.30it/s]
# train/2 6 Tomato Septoria leaf spot: 100%|██████████| 305/305 [00:10<00:00, 29.82it/s]
# train/2 7 Tomato Spider mites Two-spotted spider mite: 100%|██████████| 304/304 [00:11<00:00, 27.58it/s]
# train/2 8 Tomato Tomato mosaic virus: 100%|██████████| 313/313 [00:11<00:00, 26.43it/s]
# train/2 9 Tomato Tomato Yellow Leaf Curl Virus: 100%|██████████| 343/343 [00:12<00:00, 27.12it/s]
# train/3 1 Potato healthy: 100%|██████████| 319/319 [00:10<00:00, 30.91it/s]
# train/3 2 Potato Early blight: 100%|██████████| 339/339 [00:10<00:00, 31.16it/s]
# train/3 3 Potato Late blight: 100%|██████████| 339/339 [00:09<00:00, 34.97it/s]
# train/4 1 Grape healthy: 100%|██████████| 296/296 [00:08<00:00, 33.83it/s]
# train/4 2 Grape Black rot: 100%|██████████| 330/330 [00:09<00:00, 33.18it/s]
# train/4 3 Grape Esca (Black Measles): 100%|██████████| 336/336 [00:11<00:00, 28.35it/s]
# train/4 4 Grape Leaf blight (Isariopsis Leaf Spot): 100%|██████████| 301/301 [00:10<00:00, 29.83it/s]
# train/5 1 Corn healthy:   0%|          | 0/325 [00:00<?, ?it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:   1%|          | 4/325 [00:00<00:10, 31.49it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:   2%|▏         | 8/325 [00:00<00:09, 34.98it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:   4%|▎         | 12/325 [00:00<00:08, 36.30it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:   5%|▍         | 16/325 [00:00<00:08, 35.02it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:   7%|▋         | 24/325 [00:00<00:08, 35.97it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  10%|█         | 33/325 [00:00<00:07, 37.90it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  13%|█▎        | 41/325 [00:01<00:07, 38.53it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  15%|█▌        | 49/325 [00:01<00:07, 37.59it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  16%|█▋        | 53/325 [00:01<00:07, 37.75it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  19%|█▉        | 62/325 [00:01<00:06, 39.09it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  20%|██        | 66/325 [00:01<00:06, 37.46it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  22%|██▏       | 70/325 [00:01<00:06, 37.01it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  23%|██▎       | 74/325 [00:02<00:07, 35.68it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  24%|██▍       | 79/325 [00:02<00:06, 36.73it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  26%|██▌       | 83/325 [00:02<00:06, 36.26it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  27%|██▋       | 87/325 [00:02<00:06, 35.46it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  28%|██▊       | 91/325 [00:02<00:06, 35.07it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  30%|███       | 99/325 [00:02<00:06, 36.60it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  32%|███▏      | 103/325 [00:02<00:06, 36.87it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  37%|███▋      | 120/325 [00:03<00:05, 36.34it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  38%|███▊      | 125/325 [00:03<00:05, 37.00it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  40%|███▉      | 129/325 [00:03<00:05, 37.09it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  41%|████      | 133/325 [00:03<00:05, 36.85it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  42%|████▏     | 137/325 [00:03<00:04, 37.70it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  48%|████▊     | 156/325 [00:04<00:04, 39.40it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  50%|█████     | 164/325 [00:04<00:04, 38.23it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  53%|█████▎    | 172/325 [00:04<00:03, 38.36it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  56%|█████▌    | 181/325 [00:04<00:03, 38.52it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  57%|█████▋    | 185/325 [00:04<00:03, 38.86it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  58%|█████▊    | 190/325 [00:05<00:03, 39.93it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  60%|█████▉    | 194/325 [00:05<00:03, 38.50it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  62%|██████▏   | 202/325 [00:05<00:03, 38.08it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  63%|██████▎   | 206/325 [00:05<00:03, 38.18it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  65%|██████▍   | 211/325 [00:05<00:02, 39.56it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  67%|██████▋   | 219/325 [00:05<00:02, 38.95it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  69%|██████▊   | 223/325 [00:05<00:02, 38.24it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  70%|██████▉   | 227/325 [00:06<00:02, 38.44it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  71%|███████   | 231/325 [00:06<00:02, 38.26it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  72%|███████▏  | 235/325 [00:06<00:02, 33.37it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  74%|███████▎  | 239/325 [00:06<00:02, 34.85it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  75%|███████▍  | 243/325 [00:06<00:02, 33.89it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  80%|████████  | 261/325 [00:06<00:01, 38.10it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  82%|████████▏ | 265/325 [00:07<00:01, 37.04it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  85%|████████▍ | 275/325 [00:07<00:01, 38.40it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  86%|████████▌ | 279/325 [00:07<00:01, 37.91it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  90%|████████▉ | 291/325 [00:07<00:00, 35.67it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  91%|█████████ | 295/325 [00:07<00:00, 35.40it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  92%|█████████▏| 299/325 [00:08<00:00, 35.23it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  95%|█████████▍| 308/325 [00:08<00:00, 35.73it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy:  98%|█████████▊| 317/325 [00:08<00:00, 37.67it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 1 Corn healthy: 100%|██████████| 325/325 [00:08<00:00, 37.30it/s]
# train/5 2 Corn Common rust:  51%|█████▏    | 171/333 [00:05<00:05, 30.83it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 2 Corn Common rust: 100%|██████████| 333/333 [00:10<00:00, 31.22it/s]
# train/5 3 Corn Cercospora leaf spot Gray leaf spot:  31%|███▏      | 90/287 [00:02<00:06, 30.60it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 3 Corn Cercospora leaf spot Gray leaf spot:  34%|███▍      | 98/287 [00:03<00:05, 33.56it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 3 Corn Cercospora leaf spot Gray leaf spot:  52%|█████▏    | 150/287 [00:04<00:04, 33.27it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 3 Corn Cercospora leaf spot Gray leaf spot:  99%|█████████▊| 283/287 [00:08<00:00, 31.54it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 3 Corn Cercospora leaf spot Gray leaf spot: 100%|██████████| 287/287 [00:08<00:00, 32.18it/s]
# train/5 4 Corn Northern Leaf Blight:  50%|████▉     | 165/333 [00:05<00:05, 30.86it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 4 Corn Northern Leaf Blight:  69%|██████▉   | 229/333 [00:07<00:03, 29.61it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 4 Corn Northern Leaf Blight:  72%|███████▏  | 241/333 [00:07<00:02, 30.86it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/5 4 Corn Northern Leaf Blight: 100%|██████████| 333/333 [00:10<00:00, 31.10it/s]
# train/6 1 Strawberry healthy: 100%|██████████| 319/319 [00:10<00:00, 29.28it/s]
# train/6 2 Strawberry Leaf scorch:  26%|██▌       | 81/310 [00:02<00:07, 31.25it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# train/6 2 Strawberry Leaf scorch: 100%|██████████| 310/310 [00:09<00:00, 31.34it/s]
# train/7 1 Peach healthy: 100%|██████████| 302/302 [00:10<00:00, 28.80it/s]
# train/7 2 Peach Bacterial spot: 100%|██████████| 321/321 [00:10<00:00, 29.80it/s]
# train/8 1 Cherry healthy: 100%|██████████| 319/319 [00:10<00:00, 29.62it/s]
# train/8 2 Cherry Powdery mildew: 100%|██████████| 294/294 [00:09<00:00, 30.71it/s]
# train/9 1 Pepper bell healthy: 100%|██████████| 347/347 [00:11<00:00, 29.56it/s]
# train/9 2 Pepper bell Bacterial spot: 100%|██████████| 334/334 [00:11<00:00, 29.79it/s]
# val/1 1 Apple healthy: 100%|██████████| 75/75 [00:02<00:00, 29.34it/s]
# val/1 2 Apple Apple scab: 100%|██████████| 75/75 [00:02<00:00, 28.76it/s]
# val/1 3 Apple Black rot: 100%|██████████| 74/74 [00:02<00:00, 28.44it/s]
# val/1 4 Apple Cedar apple rust: 100%|██████████| 66/66 [00:02<00:00, 29.36it/s]
# val/2 1 Tomato healthy: 100%|██████████| 72/72 [00:02<00:00, 28.56it/s]
# val/2 2 Tomato Early blight: 100%|██████████| 72/72 [00:02<00:00, 28.99it/s]
# val/2 3 Tomato Late blight: 100%|██████████| 69/69 [00:02<00:00, 28.14it/s]
# val/2 4 Tomato Bacterial spot: 100%|██████████| 63/63 [00:02<00:00, 23.52it/s]
# val/2 5 Tomato Leaf Mold: 100%|██████████| 70/70 [00:02<00:00, 29.29it/s]
# val/2 6 Tomato Septoria leaf spot: 100%|██████████| 65/65 [00:02<00:00, 26.89it/s]
# val/2 7 Tomato Spider mites Two-spotted spider mite: 100%|██████████| 65/65 [00:02<00:00, 26.78it/s]
# val/2 8 Tomato Tomato mosaic virus: 100%|██████████| 67/67 [00:02<00:00, 29.39it/s]
# val/2 9 Tomato Tomato Yellow Leaf Curl Virus: 100%|██████████| 73/73 [00:02<00:00, 28.26it/s]
# val/3 1 Potato healthy: 100%|██████████| 68/68 [00:02<00:00, 28.71it/s]
# val/3 2 Potato Early blight: 100%|██████████| 72/72 [00:03<00:00, 23.94it/s]
# val/3 3 Potato Late blight:  26%|██▋       | 19/72 [00:00<00:01, 28.61it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/3 3 Potato Late blight: 100%|██████████| 72/72 [00:02<00:00, 28.38it/s]
# val/4 1 Grape healthy: 100%|██████████| 63/63 [00:02<00:00, 29.75it/s]
# val/4 2 Grape Black rot: 100%|██████████| 70/70 [00:02<00:00, 31.05it/s]
# val/4 3 Grape Esca (Black Measles): 100%|██████████| 72/72 [00:02<00:00, 29.54it/s]
# val/4 4 Grape Leaf blight (Isariopsis Leaf Spot): 100%|██████████| 64/64 [00:02<00:00, 30.80it/s]
# val/5 1 Corn healthy:   0%|          | 0/69 [00:00<?, ?it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  12%|█▏        | 8/69 [00:00<00:01, 33.87it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  17%|█▋        | 12/69 [00:00<00:01, 34.86it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  29%|██▉       | 20/69 [00:00<00:01, 35.52it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  48%|████▊     | 33/69 [00:00<00:01, 35.43it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  65%|██████▌   | 45/69 [00:01<00:00, 36.64it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  71%|███████   | 49/69 [00:01<00:00, 36.52it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  83%|████████▎ | 57/69 [00:01<00:00, 35.95it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy:  96%|█████████▌| 66/69 [00:01<00:00, 35.41it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# val/5 1 Corn healthy: 100%|██████████| 69/69 [00:01<00:00, 35.93it/s]
# val/5 2 Corn Common rust: 100%|██████████| 71/71 [00:02<00:00, 30.99it/s]
# val/5 3 Corn Cercospora leaf spot Gray leaf spot: 100%|██████████| 61/61 [00:01<00:00, 32.94it/s]
# val/5 4 Corn Northern Leaf Blight: 100%|██████████| 71/71 [00:02<00:00, 32.83it/s]
# val/6 1 Strawberry healthy: 100%|██████████| 68/68 [00:02<00:00, 29.56it/s]
# val/6 2 Strawberry Leaf scorch: 100%|██████████| 66/66 [00:02<00:00, 31.13it/s]
# val/7 1 Peach healthy: 100%|██████████| 64/64 [00:02<00:00, 29.16it/s]
# val/7 2 Peach Bacterial spot: 100%|██████████| 68/68 [00:02<00:00, 27.41it/s]
# val/8 1 Cherry healthy: 100%|██████████| 68/68 [00:02<00:00, 23.88it/s]
# val/8 2 Cherry Powdery mildew: 100%|██████████| 63/63 [00:02<00:00, 28.15it/s]
# val/9 1 Pepper bell healthy: 100%|██████████| 74/74 [00:02<00:00, 30.22it/s]
# val/9 2 Pepper bell Bacterial spot: 100%|██████████| 71/71 [00:02<00:00, 26.94it/s]
# test/1 1 Apple healthy: 100%|██████████| 76/76 [00:02<00:00, 28.16it/s]
# test/1 2 Apple Apple scab: 100%|██████████| 77/77 [00:02<00:00, 30.39it/s]
# test/1 3 Apple Black rot: 100%|██████████| 76/76 [00:03<00:00, 23.45it/s]
# test/1 4 Apple Cedar apple rust: 100%|██████████| 66/66 [00:02<00:00, 30.38it/s]
# test/2 1 Tomato healthy: 100%|██████████| 73/73 [00:02<00:00, 29.33it/s]
# test/2 2 Tomato Early blight: 100%|██████████| 72/72 [00:02<00:00, 28.34it/s]
# test/2 3 Tomato Late blight: 100%|██████████| 70/70 [00:02<00:00, 31.40it/s]
# test/2 4 Tomato Bacterial spot: 100%|██████████| 65/65 [00:02<00:00, 30.53it/s]
# test/2 5 Tomato Leaf Mold: 100%|██████████| 71/71 [00:02<00:00, 27.11it/s]
# test/2 6 Tomato Septoria leaf spot: 100%|██████████| 66/66 [00:02<00:00, 27.65it/s]
# test/2 7 Tomato Spider mites Two-spotted spider mite: 100%|██████████| 66/66 [00:02<00:00, 28.37it/s]
# test/2 8 Tomato Tomato mosaic virus: 100%|██████████| 68/68 [00:02<00:00, 29.24it/s]
# test/2 9 Tomato Tomato Yellow Leaf Curl Virus: 100%|██████████| 74/74 [00:02<00:00, 28.35it/s]
# test/3 1 Potato healthy: 100%|██████████| 69/69 [00:02<00:00, 28.10it/s]
# test/3 2 Potato Early blight: 100%|██████████| 74/74 [00:02<00:00, 28.08it/s]
# test/3 3 Potato Late blight: 100%|██████████| 74/74 [00:02<00:00, 25.81it/s]
# test/4 1 Grape healthy: 100%|██████████| 64/64 [00:02<00:00, 27.85it/s]
# test/4 2 Grape Black rot: 100%|██████████| 72/72 [00:02<00:00, 29.37it/s]
# test/4 3 Grape Esca (Black Measles): 100%|██████████| 72/72 [00:02<00:00, 27.02it/s]
# test/4 4 Grape Leaf blight (Isariopsis Leaf Spot): 100%|██████████| 65/65 [00:02<00:00, 29.61it/s]
# test/5 1 Corn healthy:   0%|          | 0/71 [00:00<?, ?it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:   6%|▌         | 4/71 [00:00<00:01, 39.00it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  11%|█▏        | 8/71 [00:00<00:01, 36.69it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  28%|██▊       | 20/71 [00:00<00:01, 36.60it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  35%|███▌      | 25/71 [00:00<00:01, 38.10it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  41%|████      | 29/71 [00:00<00:01, 38.32it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  46%|████▋     | 33/71 [00:00<00:01, 37.65it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  66%|██████▌   | 47/71 [00:01<00:00, 38.13it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  77%|███████▋  | 55/71 [00:01<00:00, 35.96it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  83%|████████▎ | 59/71 [00:01<00:00, 36.03it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy:  90%|█████████ | 64/71 [00:01<00:00, 37.84it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 1 Corn healthy: 100%|██████████| 71/71 [00:01<00:00, 37.01it/s]
# test/5 2 Corn Common rust:  47%|████▋     | 34/73 [00:01<00:01, 31.42it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 2 Corn Common rust: 100%|██████████| 73/73 [00:02<00:00, 29.88it/s]
# test/5 3 Corn Cercospora leaf spot Gray leaf spot:  85%|████████▌ | 53/62 [00:01<00:00, 32.77it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 3 Corn Cercospora leaf spot Gray leaf spot: 100%|██████████| 62/62 [00:02<00:00, 30.15it/s]
# test/5 4 Corn Northern Leaf Blight:  79%|███████▉  | 58/73 [00:01<00:00, 32.02it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 4 Corn Northern Leaf Blight:  85%|████████▍ | 62/73 [00:01<00:00, 32.09it/s]C:\Users\rakti\anaconda3\envs\power\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# test/5 4 Corn Northern Leaf Blight: 100%|██████████| 73/73 [00:02<00:00, 32.36it/s]
# test/6 1 Strawberry healthy: 100%|██████████| 69/69 [00:02<00:00, 29.60it/s]
# test/6 2 Strawberry Leaf scorch: 100%|██████████| 68/68 [00:02<00:00, 28.82it/s]
# test/7 1 Peach healthy: 100%|██████████| 66/66 [00:02<00:00, 30.09it/s]
# test/7 2 Peach Bacterial spot: 100%|██████████| 70/70 [00:02<00:00, 30.69it/s]
# test/8 1 Cherry healthy: 100%|██████████| 69/69 [00:02<00:00, 28.93it/s]
# test/8 2 Cherry Powdery mildew: 100%|██████████| 64/64 [00:02<00:00, 28.32it/s]
# test/9 1 Pepper bell healthy: 100%|██████████| 76/76 [00:02<00:00, 29.15it/s]
# test/9 2 Pepper bell Bacterial spot: 100%|██████████| 73/73 [00:02<00:00, 27.51it/s]
# Segmentation complete. Segmented images saved under dest_root.

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm


def remove_background_grabcut(image_path, iter_count=5):
    """
    Removes the background from an image using OpenCV's GrabCut algorithm.
    Returns an RGBA image (foreground intact, background transparent).
    """
    img = cv2.imread(image_path)
    if img is None:
        return None
    # Initialize mask, bgdModel, fgdModel
    mask = np.zeros(img.shape[:2], np.uint8)
    bgdModel = np.zeros((1, 65), np.float64)
    fgdModel = np.zeros((1, 65), np.float64)
    # Define initial rectangle (slightly inset)
    h, w = img.shape[:2]
    rect = (10, 10, w - 20, h - 20)
    # Apply GrabCut
    cv2.grabCut(img, mask, rect, bgdModel, fgdModel, iterCount=iter_count, mode=cv2.GC_INIT_WITH_RECT)
    # Prepare mask: 0,2 => background; 1,3 => foreground
    mask2 = np.where((mask == cv2.GC_BGD) | (mask == cv2.GC_PR_BGD), 0, 1).astype('uint8')
    # Extract foreground
    fg = img * mask2[:, :, np.newaxis]
    # Create transparent background
    b, g, r = cv2.split(fg)
    alpha = mask2 * 255
    rgba = cv2.merge([b, g, r, alpha])
    return rgba


def process_remove_background(source_root, dest_root):
    """
    Traverse the dataset directory structured as source_root/{train,val,test}/{class_name}/
    Remove background from each image and save as PNG with transparency in dest_root,
    preserving the same split and class folder structure.
    """
    splits = ['train', 'val', 'test']
    for split in splits:
        src_split = os.path.join(source_root, split)
        dst_split = os.path.join(dest_root, split)
        if not os.path.isdir(src_split):
            continue
        for class_name in os.listdir(src_split):
            src_class = os.path.join(src_split, class_name)
            dst_class = os.path.join(dst_split, class_name)
            if not os.path.isdir(src_class):
                continue
            os.makedirs(dst_class, exist_ok=True)
            for img_file in tqdm(os.listdir(src_class), desc=f"Removing bg {split}/{class_name}"):
                if not img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    continue
                src_img = os.path.join(src_class, img_file)
                rgba = remove_background_grabcut(src_img)
                if rgba is None:
                    continue
                # Save with same filename but as PNG to keep alpha channel
                name, _ = os.path.splitext(img_file)
                dst_img = os.path.join(dst_class, f"{name}.png")
                cv2.imwrite(dst_img, rgba)
    print("Background removal complete. Images saved under dest_root.")


if __name__ == '__main__':
    source_root = r"C:\Users\rakti\Downloads\a\Final-project\Datasets\New Plant Disease Dataset ttv"
    dest_root   = r"C:\Users\rakti\Downloads\a\Final-project\Datasets\npld_bg_removed"
    process_remove_background(source_root, dest_root)
# Out:
# Removing bg train/1 1 Apple healthy: 100%|██████████| 351/351 [01:20<00:00,  4.35it/s]
# Removing bg train/1 2 Apple Apple scab: 100%|██████████| 352/352 [01:37<00:00,  3.61it/s]
# Removing bg train/1 3 Apple Black rot: 100%|██████████| 347/347 [01:01<00:00,  5.60it/s]
# Removing bg train/1 4 Apple Cedar apple rust: 100%|██████████| 308/308 [01:32<00:00,  3.35it/s]
# Removing bg train/2 1 Tomato healthy: 100%|██████████| 336/336 [01:24<00:00,  3.99it/s]
# Removing bg train/2 2 Tomato Early blight: 100%|██████████| 336/336 [01:36<00:00,  3.50it/s]
# Removing bg train/2 3 Tomato Late blight: 100%|██████████| 324/324 [02:02<00:00,  2.64it/s]
# Removing bg train/2 4 Tomato Bacterial spot: 100%|██████████| 297/297 [01:04<00:00,  4.59it/s]
# Removing bg train/2 5 Tomato Leaf Mold: 100%|██████████| 329/329 [01:36<00:00,  3.40it/s]
# Removing bg train/2 6 Tomato Septoria leaf spot: 100%|██████████| 305/305 [01:17<00:00,  3.92it/s]
# Removing bg train/2 7 Tomato Spider mites Two-spotted spider mite: 100%|██████████| 304/304 [01:04<00:00,  4.68it/s]
# Removing bg train/2 8 Tomato Tomato mosaic virus: 100%|██████████| 313/313 [01:41<00:00,  3.09it/s]
# Removing bg train/2 9 Tomato Tomato Yellow Leaf Curl Virus: 100%|██████████| 343/343 [01:31<00:00,  3.75it/s]
# Removing bg train/3 1 Potato healthy: 100%|██████████| 319/319 [00:58<00:00,  5.46it/s]
# Removing bg train/3 2 Potato Early blight: 100%|██████████| 339/339 [01:00<00:00,  5.58it/s]
# Removing bg train/3 3 Potato Late blight: 100%|██████████| 339/339 [01:04<00:00,  5.24it/s]
# Removing bg train/4 1 Grape healthy: 100%|██████████| 296/296 [00:53<00:00,  5.49it/s]
# Removing bg train/4 2 Grape Black rot: 100%|██████████| 330/330 [01:07<00:00,  4.88it/s]
# Removing bg train/4 3 Grape Esca (Black Measles): 100%|██████████| 336/336 [01:06<00:00,  5.07it/s]
# Removing bg train/4 4 Grape Leaf blight (Isariopsis Leaf Spot): 100%|██████████| 301/301 [01:03<00:00,  4.75it/s]
# Removing bg train/5 1 Corn healthy: 100%|██████████| 325/325 [03:17<00:00,  1.65it/s]
# Removing bg train/5 2 Corn Common rust: 100%|██████████| 333/333 [03:25<00:00,  1.62it/s]
# Removing bg train/5 3 Corn Cercospora leaf spot Gray leaf spot: 100%|██████████| 287/287 [03:37<00:00,  1.32it/s]
# Removing bg train/5 4 Corn Northern Leaf Blight: 100%|██████████| 333/333 [04:01<00:00,  1.38it/s]
# Removing bg train/6 1 Strawberry healthy: 100%|██████████| 319/319 [01:02<00:00,  5.10it/s]
# Removing bg train/6 2 Strawberry Leaf scorch: 100%|██████████| 310/310 [01:23<00:00,  3.71it/s]
# Removing bg train/7 1 Peach healthy: 100%|██████████| 302/302 [01:00<00:00,  4.95it/s]
# Removing bg train/7 2 Peach Bacterial spot: 100%|██████████| 321/321 [01:43<00:00,  3.09it/s]
# Removing bg train/8 1 Cherry healthy: 100%|██████████| 319/319 [00:46<00:00,  6.84it/s]
# Removing bg train/8 2 Cherry Powdery mildew: 100%|██████████| 294/294 [00:56<00:00,  5.25it/s]
# Removing bg train/9 1 Pepper bell healthy: 100%|██████████| 347/347 [00:54<00:00,  6.37it/s]
# Removing bg train/9 2 Pepper bell Bacterial spot: 100%|██████████| 334/334 [00:55<00:00,  5.98it/s]
# Removing bg val/1 1 Apple healthy: 100%|██████████| 75/75 [00:17<00:00,  4.27it/s]
# Removing bg val/1 2 Apple Apple scab: 100%|██████████| 75/75 [00:22<00:00,  3.31it/s]
# Removing bg val/1 3 Apple Black rot: 100%|██████████| 74/74 [00:13<00:00,  5.41it/s]
# Removing bg val/1 4 Apple Cedar apple rust: 100%|██████████| 66/66 [00:19<00:00,  3.46it/s]
# Removing bg val/2 1 Tomato healthy: 100%|██████████| 72/72 [00:17<00:00,  4.22it/s]
# Removing bg val/2 2 Tomato Early blight: 100%|██████████| 72/72 [00:21<00:00,  3.39it/s]
# Removing bg val/2 3 Tomato Late blight: 100%|██████████| 69/69 [00:25<00:00,  2.74it/s]
# Removing bg val/2 4 Tomato Bacterial spot: 100%|██████████| 63/63 [00:13<00:00,  4.68it/s]
# Removing bg val/2 5 Tomato Leaf Mold: 100%|██████████| 70/70 [00:21<00:00,  3.31it/s]
# Removing bg val/2 6 Tomato Septoria leaf spot: 100%|██████████| 65/65 [00:19<00:00,  3.39it/s]
# Removing bg val/2 7 Tomato Spider mites Two-spotted spider mite: 100%|██████████| 65/65 [00:15<00:00,  4.28it/s]
# Removing bg val/2 8 Tomato Tomato mosaic virus: 100%|██████████| 67/67 [00:22<00:00,  2.93it/s]
# Removing bg val/2 9 Tomato Tomato Yellow Leaf Curl Virus: 100%|██████████| 73/73 [00:22<00:00,  3.27it/s]
# Removing bg val/3 1 Potato healthy: 100%|██████████| 68/68 [00:12<00:00,  5.24it/s]
# Removing bg val/3 2 Potato Early blight: 100%|██████████| 72/72 [00:13<00:00,  5.48it/s]
# Removing bg val/3 3 Potato Late blight: 100%|██████████| 72/72 [00:15<00:00,  4.80it/s]
# Removing bg val/4 1 Grape healthy: 100%|██████████| 63/63 [00:12<00:00,  5.18it/s]
# Removing bg val/4 2 Grape Black rot: 100%|██████████| 70/70 [00:15<00:00,  4.48it/s]
# Removing bg val/4 3 Grape Esca (Black Measles): 100%|██████████| 72/72 [00:14<00:00,  5.11it/s]
# Removing bg val/4 4 Grape Leaf blight (Isariopsis Leaf Spot): 100%|██████████| 64/64 [00:13<00:00,  4.66it/s]
# Removing bg val/5 1 Corn healthy: 100%|██████████| 69/69 [00:42<00:00,  1.63it/s]
# Removing bg val/5 2 Corn Common rust: 100%|██████████| 71/71 [00:49<00:00,  1.44it/s]
# Removing bg val/5 3 Corn Cercospora leaf spot Gray leaf spot: 100%|██████████| 61/61 [00:48<00:00,  1.26it/s]
# Removing bg val/5 4 Corn Northern Leaf Blight: 100%|██████████| 71/71 [00:54<00:00,  1.30it/s]
# Removing bg val/6 1 Strawberry healthy: 100%|██████████| 68/68 [00:14<00:00,  4.79it/s]
# Removing bg val/6 2 Strawberry Leaf scorch: 100%|██████████| 66/66 [00:20<00:00,  3.24it/s]
# Removing bg val/7 1 Peach healthy: 100%|██████████| 64/64 [00:15<00:00,  4.19it/s]
# Removing bg val/7 2 Peach Bacterial spot: 100%|██████████| 68/68 [00:21<00:00,  3.18it/s]
# Removing bg val/8 1 Cherry healthy: 100%|██████████| 68/68 [00:10<00:00,  6.60it/s]
# Removing bg val/8 2 Cherry Powdery mildew: 100%|██████████| 63/63 [00:12<00:00,  5.12it/s]
# Removing bg val/9 1 Pepper bell healthy: 100%|██████████| 74/74 [00:13<00:00,  5.62it/s]
# Removing bg val/9 2 Pepper bell Bacterial spot: 100%|██████████| 71/71 [00:14<00:00,  5.06it/s]
# Removing bg test/1 1 Apple healthy: 100%|██████████| 76/76 [00:18<00:00,  4.18it/s]
# Removing bg test/1 2 Apple Apple scab: 100%|██████████| 77/77 [00:22<00:00,  3.48it/s]
# Removing bg test/1 3 Apple Black rot: 100%|██████████| 76/76 [00:15<00:00,  4.91it/s]
# Removing bg test/1 4 Apple Cedar apple rust: 100%|██████████| 66/66 [00:22<00:00,  2.90it/s]
# Removing bg test/2 1 Tomato healthy: 100%|██████████| 73/73 [00:18<00:00,  3.98it/s]
# Removing bg test/2 2 Tomato Early blight: 100%|██████████| 72/72 [00:20<00:00,  3.44it/s]
# Removing bg test/2 3 Tomato Late blight: 100%|██████████| 70/70 [00:25<00:00,  2.74it/s]
# Removing bg test/2 4 Tomato Bacterial spot: 100%|██████████| 65/65 [00:14<00:00,  4.57it/s]
# Removing bg test/2 5 Tomato Leaf Mold: 100%|██████████| 71/71 [00:21<00:00,  3.34it/s]
# Removing bg test/2 6 Tomato Septoria leaf spot: 100%|██████████| 66/66 [00:18<00:00,  3.60it/s]
# Removing bg test/2 7 Tomato Spider mites Two-spotted spider mite: 100%|██████████| 66/66 [00:14<00:00,  4.48it/s]
# Removing bg test/2 8 Tomato Tomato mosaic virus: 100%|██████████| 68/68 [00:21<00:00,  3.20it/s]
# Removing bg test/2 9 Tomato Tomato Yellow Leaf Curl Virus: 100%|██████████| 74/74 [00:23<00:00,  3.18it/s]
# Removing bg test/3 1 Potato healthy: 100%|██████████| 69/69 [00:12<00:00,  5.39it/s]
# Removing bg test/3 2 Potato Early blight: 100%|██████████| 74/74 [00:13<00:00,  5.31it/s]
# Removing bg test/3 3 Potato Late blight: 100%|██████████| 74/74 [00:16<00:00,  4.49it/s]
# Removing bg test/4 1 Grape healthy: 100%|██████████| 64/64 [00:13<00:00,  4.79it/s]
# Removing bg test/4 2 Grape Black rot: 100%|██████████| 72/72 [00:14<00:00,  4.84it/s]
# Removing bg test/4 3 Grape Esca (Black Measles): 100%|██████████| 72/72 [00:13<00:00,  5.28it/s]
# Removing bg test/4 4 Grape Leaf blight (Isariopsis Leaf Spot): 100%|██████████| 65/65 [00:13<00:00,  4.79it/s]
# Removing bg test/5 1 Corn healthy: 100%|██████████| 71/71 [00:43<00:00,  1.64it/s]
# Removing bg test/5 2 Corn Common rust: 100%|██████████| 73/73 [00:50<00:00,  1.45it/s]
# Removing bg test/5 3 Corn Cercospora leaf spot Gray leaf spot: 100%|██████████| 62/62 [00:47<00:00,  1.29it/s]
# Removing bg test/5 4 Corn Northern Leaf Blight: 100%|██████████| 73/73 [00:51<00:00,  1.42it/s]
# Removing bg test/6 1 Strawberry healthy: 100%|██████████| 69/69 [00:13<00:00,  5.12it/s]
# Removing bg test/6 2 Strawberry Leaf scorch: 100%|██████████| 68/68 [00:19<00:00,  3.53it/s]
# Removing bg test/7 1 Peach healthy: 100%|██████████| 66/66 [00:14<00:00,  4.68it/s]
# Removing bg test/7 2 Peach Bacterial spot: 100%|██████████| 70/70 [00:23<00:00,  2.95it/s]
# Removing bg test/8 1 Cherry healthy: 100%|██████████| 69/69 [00:10<00:00,  6.86it/s]
# Removing bg test/8 2 Cherry Powdery mildew: 100%|██████████| 64/64 [00:12<00:00,  5.00it/s]
# Removing bg test/9 1 Pepper bell healthy: 100%|██████████| 76/76 [00:12<00:00,  6.27it/s]
# Removing bg test/9 2 Pepper bell Bacterial spot: 100%|██████████| 73/73 [00:12<00:00,  5.83it/s]
# Background removal complete. Images saved under dest_root.
